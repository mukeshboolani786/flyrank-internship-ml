# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mukeshboolani786/flyrank-internship-ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# My lane is primarily a ranking task. The goal is to prioritize webpages based on how likely they are to need a content refresh so that the SEO team knows which pages to review first. A binary classification model can estimate the probability that a page is declining, and those probabilities can then be used to rank the pages from highest to lowest priority.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The target variable is is_declining_label. This label is created from the trend_direction column using a predefined rule. If a page is identified as declining, the label is set accordingly. The model learns to predict this label using the available page features instead of using the rule directly.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The success metric is Precision@50. The SEO team can only review a limited number of pages, so the model should recommend the pages that are most likely to need attention. Precision@50 measures how many of the top 50 recommended pages are actually declining. A higher Precision@50 means the model is helping the team spend its time on the right pages.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The unit of analysis is one content page (webpage). Each row in the dataframe represents a single webpage and contains its SEO-related information, such as clicks, impressions, CTR, ranking position, and other features. The model makes one prediction for each page to determine its priority for review.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Machine learning is a better solution than a fixed rule because webpage performance depends on many features working together. Factors such as clicks, impressions, CTR, ranking position, search volume, engagement, and content characteristics all influence whether a page should be refreshed. A simple rule like if CTR < 2% cannot capture these complex relationships and may produce poor recommendations. Machine learning learns patterns from historical data and combines many features to identify the pages that should be refreshed first, leading to better decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# I identified the ML task as a ranking problem.
# I identified the target variable as is_declining_label.
# I selected Precision@50 as the success metric and explained why it matches the business goal.
# I showed that one row in the dataframe represents one content page.
# I explained why machine learning is more suitable than a fixed rule for this problem.
# I verified that the notebook runs successfully from top to bottom and that my explanations are based on the provided data and documentation.
